# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\shree\OneDrive\Documents\my excel\Bmi_male_female.csv")
df.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
x=df[["Height","Weight"]]
y=df.Gender

# %%
Y=pd.get_dummies(y)
x
# Out:
#      Height  Weight
# 0       174      96
# 1       189      87
# 2       185     110
# 3       195     104
# 4       149      61
# ..      ...     ...
# 495     150     153
# 496     184     121
# 497     141     136
# 498     150      95
# 499     173     131
#
# [500 rows x 2 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
import warnings
warnings.filterwarnings("ignore")

# %%
model=DecisionTreeClassifier()

# %%
model.fit(x,Y)
# Out:
# DecisionTreeClassifier()

# %%
ans = model.predict([[130,90]])

# %%
if ans[0][0]==True:
    print ("Female")
else:
    print("Male")
# Out:
# Male

# %%
ans
# Out:
# array([[False,  True]])

# %% [markdown]
# Label Encoding

# %%
x.head()
# Out:
#    Height  Weight
# 0     174      96
# 1     189      87
# 2     185     110
# 3     195     104
# 4     149      61

# %%
y
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4        Male
#         ...
# 495    Female
# 496    Female
# 497    Female
# 498      Male
# 499      Male
# Name: Gender, Length: 500, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
Y1=le.fit_transform(y)

# %%
model1=DecisionTreeClassifier()

# %%
model1.fit(x,Y1)
# Out:
# DecisionTreeClassifier()

# %%
if model1.predict([[190,50]])[0]==0:
    print("Female")
else:
    print("Male")
# Out:
# Female

# %%
if model1.predict([[170,80]])[0]==0:
    print("Female")
else:
    print("Male")
# Out:
# Male
